# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
import pandas as pd
import numpy as np
from numpy import asarray

# %%
df_profile = pd.read_excel("A2 - Profile.xlsx")
df_survey = pd.read_excel("A2 - Survey.xlsx")

# %%
df_merged = df_profile.merge(df_survey, left_on="CustomerID", right_on="customerID", how="inner")
df_merged
#df_test = OneHotEncoder.fit_transform(df_merged[["Job"]])
# Out:
#       CustomerID   Age           Job Marital_status          Education  \
# 0              1  30.0   blue-collar        married           basic.9y
# 1              1  30.0   blue-collar        married           basic.9y
# 2              2  39.0      services         single        high.school
# 3              2  39.0      services         single        high.school
# 4              3  25.0      services        married        high.school
# ...          ...   ...           ...            ...                ...
# 2269        1825  34.0      services        married        high.school
# 2270        1826  49.0    management        married  university.degree
# 2271        1827  50.0   blue-collar       divorced           basic.4y
# 2272        1828  51.0  entrepreneur        married  university.degree
# 2273        1829  57.0       retired        married  university.degree
#
#      Credict_Payment  customerID Shopping type  Product-quality  Deli-quality  \
# ...

# %%
df_merged["Job"].unique()
#ohe = OneHotEncoder(sparse_output= False, handle_unknown='ignore')
#enc = OneHotEncoder(handle_unknown='ignore').fit_transform(df_merged['Job'])

#enc = pd.get_dummies(df_merged['Job'])
enc = OrdinalEncoder()
ting = asarray([df_merged['Job']])
enc.fit_transform(ting)
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
# Out:
# array([['red'],
#        ['green'],
#        ['blue']], dtype='<U5')

# %%
X = df_merged[["Age", "Job", "Marital_status", "Education", "Credict_Payment"]]
Y = df_merged["Shopping type"]
clf = DecisionTreeClassifier()
clf = clf.fit(X, Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       2 Y = df_merged["Shopping type"]
#       3 clf = DecisionTreeClassifier()
# ----> 4 clf = clf.fit(X, Y)
#
# File c:\Users\annguyen\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\tree\_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# ...
